# %%
import pandas as pd

df = pd.read_parquet("artifacts/identify/react_semgrep_results_df.parquet")
print(df[['cve_id', 'path', 'start_line']].head(16))
# Out:
#             cve_id                                               path  \
# 0   CVE-2020-14001                                               None
# 1    CVE-2019-5477                                               None
# 2    CVE-2015-8806                                               None
# 3   CVE-2022-29181                                               None
# 4   CVE-2022-29181                                               None
# 5   CVE-2019-18197                                               None
# 6   CVE-2019-18197                                               None
# 7    CVE-2017-5029                                               None
# 8   CVE-2017-16516                                               None
# 9   CVE-2022-24836                                               None
# 10  CVE-2022-24836                                               None
# 11  CVE-2020-26247                                               None
# 12  CVE-2022-24795                                               None
# 13  CVE-2022-24795                                               None
# 14  CVE-2021-41098                                               None
# 15  CVE-2018-17567  artifacts/identify/repos/jekyll/lib/jekyll/com...
#
#     start_line
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15      1091.0
